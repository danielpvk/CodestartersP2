# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_inegi = "./Resources/csv/BIE_BIE20190523193335.csv"

# %%
PIB_df = pd.read_csv(csv_inegi,encoding ='latin1')

# %%
PIB_df.head(5)
# Out:
#            Entidad                                             Sector  \
# 0   Aguascalientes                                            Minería
# 1   Aguascalientes  Generación, transmisión y distribución de ener...
# 2   Aguascalientes                                       Construcción
# 3   Aguascalientes                          Industrias manufactureras
# 4  Baja California                            Actividades secundarias
#
#       2018/01     2018/02     2018/03     2018/04     2018/05     2018/06  \
# 0   71.581928   74.538138   81.759683   72.966245   76.021630   67.741930
# 1  123.135766  125.902232  116.336919  131.971976  122.666208  134.363338
# 2  122.091917  130.383091  126.659724  113.136473  115.405914  108.993267
# 3  156.279936  137.011376  143.705521  130.896569  143.841126  147.869162
# 4  119.017000  118.761771  122.218695  120.953159  123.841961  124.877570
#
#       2018/07     2018/08     2018/09     2018/10     2018/11     2018/12  \
# 0   70.577510   75.160746   73.241484   71.103056   78.240948   67.380510
# 1  128.927324  124.895400  135.179778  133.347974  142.452951  126.612567
# 2  116.819366  116.504343  117.430186  121.931559  126.966549  118.115246
# 3  123.645452  153.326693  148.927985  161.185942  158.353279  125.159600
# 4  127.481205  131.474620  128.187831  133.690253  127.974122  121.101113
#
#       2019/01
# 0   61.900116
# 1  127.888741
# 2  115.432118
# 3  127.898922
# 4  128.953189

# %%
PIB_df = PIB_df.rename(columns={'Entidad': 'Estado_calculado'})

# %%
PIB_df.columns
# Out:
# Index(['Estado_calculado', 'Sector', '2018/01', '2018/02', '2018/03',
#        '2018/04', '2018/05', '2018/06', '2018/07', '2018/08', '2018/09',
#        '2018/10', '2018/11', '2018/12', '2019/01'],
#       dtype='object')

# %%
PIB_df['Estado_calculado'] = PIB_df['Estado_calculado'].str.upper()
PIB_df.head()
# Out:
#   Estado_calculado                                             Sector  \
# 0   AGUASCALIENTES                                            Minería
# 1   AGUASCALIENTES  Generación, transmisión y distribución de ener...
# 2   AGUASCALIENTES                                       Construcción
# 3   AGUASCALIENTES                          Industrias manufactureras
# 4  BAJA CALIFORNIA                            Actividades secundarias
#
#       2018/01     2018/02     2018/03     2018/04     2018/05     2018/06  \
# 0   71.581928   74.538138   81.759683   72.966245   76.021630   67.741930
# 1  123.135766  125.902232  116.336919  131.971976  122.666208  134.363338
# 2  122.091917  130.383091  126.659724  113.136473  115.405914  108.993267
# 3  156.279936  137.011376  143.705521  130.896569  143.841126  147.869162
# 4  119.017000  118.761771  122.218695  120.953159  123.841961  124.877570
#
#       2018/07     2018/08     2018/09     2018/10     2018/11     2018/12  \
# 0   70.577510   75.160746   73.241484   71.103056   78.240948   67.380510
# 1  128.927324  124.895400  135.179778  133.347974  142.452951  126.612567
# 2  116.819366  116.504343  117.430186  121.931559  126.966549  118.115246
# 3  123.645452  153.326693  148.927985  161.185942  158.353279  125.159600
# 4  127.481205  131.474620  128.187831  133.690253  127.974122  121.101113
#
#       2019/01
# 0   61.900116
# 1  127.888741
# 2  115.432118
# 3  127.898922
# 4  128.953189

# %%
PIB_df = PIB_df.rename(columns={'Sector': 'Actividad_economica_agragada'})
PIB_df.head()
# Out:
#   Estado_calculado                       Actividad_economica_agragada  \
# 0   AGUASCALIENTES                                            Minería
# 1   AGUASCALIENTES  Generación, transmisión y distribución de ener...
# 2   AGUASCALIENTES                                       Construcción
# 3   AGUASCALIENTES                          Industrias manufactureras
# 4  BAJA CALIFORNIA                            Actividades secundarias
#
#       2018/01     2018/02     2018/03     2018/04     2018/05     2018/06  \
# 0   71.581928   74.538138   81.759683   72.966245   76.021630   67.741930
# 1  123.135766  125.902232  116.336919  131.971976  122.666208  134.363338
# 2  122.091917  130.383091  126.659724  113.136473  115.405914  108.993267
# 3  156.279936  137.011376  143.705521  130.896569  143.841126  147.869162
# 4  119.017000  118.761771  122.218695  120.953159  123.841961  124.877570
#
#       2018/07     2018/08     2018/09     2018/10     2018/11     2018/12  \
# 0   70.577510   75.160746   73.241484   71.103056   78.240948   67.380510
# 1  128.927324  124.895400  135.179778  133.347974  142.452951  126.612567
# 2  116.819366  116.504343  117.430186  121.931559  126.966549  118.115246
# 3  123.645452  153.326693  148.927985  161.185942  158.353279  125.159600
# 4  127.481205  131.474620  128.187831  133.690253  127.974122  121.101113
#
#       2019/01
# 0   61.900116
# 1  127.888741
# 2  115.432118
# 3  127.898922
# 4  128.953189

# %%
rds_connection_string =  "ijumrmphpxjghs:60e1c244346de108f89c7a6cc7d27ef39cd59f3ed35012bf153c18a8d0a32264@ec2-107-20-230-70.compute-1.amazonaws.com:5432/d4m36o9apelhp0"

# %%
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
PIB_df.to_sql(name='pib_data', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "ijumrmphpxjghs"
# FATAL:  no pg_hba.conf entry for host "189.216.140.159", user "ijumrmphpxjghs", database "d4m36o9apelhp0", SSL off
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-fde3b26b9acc> in <module>
# ----> 1 PIB_df.to_sql(name='pib_data', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1124                          if_exists=if_exists, index_label=index_label,
#    1125                          schema=schema, dtype=dtype)
# -> 1126         table.create()
#    1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\pandas\io\sql.py in create(self)
#     559
#     560     def create(self):
# --> 561         if self.exists():
#     562             if self.if_exists == 'fail':
#     563                 raise ValueError("Table '%s' already exists." % self.name)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\pandas\io\sql.py in exists(self)
#     547
#     548     def exists(self):
# --> 549         return self.pd_sql.has_table(self.name, self.schema)
#     550
#     551     def sql_schema(self):
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1152             self.connectable.dialect.has_table,
#    1153             name,
# -> 1154             schema or self.meta.schema,
#    1155         )
#    1156
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2053
#    2054         """
# -> 2055         with self.contextual_connect() as conn:
#    2056             return conn.run_callable(callable_, *args, **kwargs)
#    2057
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\base.py in contextual_connect(self, close_with_result, **kwargs)
#    2121         return self._connection_cls(
#    2122             self,
# -> 2123             self._wrap_pool_connect(self.pool.connect, None),
#    2124             close_with_result=close_with_result,
#    2125             **kwargs)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     398         """
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#     402         try:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     786     def _checkout(cls, pool, threadconns=None, fairy=None):
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#     790             fairy._pool = pool
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     527     @classmethod
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#     531             dbapi_connection = rec.get_connection()
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1191             except:
#    1192                 with util.safe_reraise():
# -> 1193                     self._dec_overflow()
#    1194         else:
#    1195             return self._do_get()
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1188         if self._inc_overflow():
#    1189             try:
# -> 1190                 return self._create_connection()
#    1191             except:
#    1192                 with util.safe_reraise():
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     345         """Called by subclasses to create a new ConnectionRecord."""
#     346
# --> 347         return _ConnectionRecord(self)
#     348
#     349     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     472         self.__pool = pool
#     473         if connect:
# --> 474             self.__connect(first_connect_check=True)
#     475         self.finalize_callback = deque()
#     476
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     669         try:
#     670             self.starttime = time.time()
# --> 671             connection = pool._invoke_creator(self)
#     672             pool.logger.debug("Created new connection %r", connection)
#     673             self.connection = connection
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     410
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#     414     def create_connect_args(self, url):
#
# ~\Anaconda3\envs\pythonrules\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "ijumrmphpxjghs"
# FATAL:  no pg_hba.conf entry for host "189.216.140.159", user "ijumrmphpxjghs", database "d4m36o9apelhp0", SSL off
#  (Background on this error at: http://sqlalche.me/e/e3q8)
